# %%
import pandas as pd

# %%
df = pd.read_csv("onlineShop.csv")
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
clothing = df[df["Product Category"] == "Clothing"]
clothing
# Out:
#      Transaction ID        Date Product Category  \
# 2             10003  2024-01-03         Clothing
# 8             10009  2024-01-09         Clothing
# 14            10015  2024-01-15         Clothing
# 20            10021  2024-01-21         Clothing
# 26            10027  2024-01-27         Clothing
# 32            10033  2024-02-02         Clothing
# 38            10039  2024-02-08         Clothing
# 44            10045  2024-02-14         Clothing
# 50            10051  2024-02-20         Clothing
# 56            10057  2024-02-26         Clothing
# 62            10063  2024-03-03         Clothing
# 68            10069  2024-03-09         Clothing
# 74            10075  2024-03-15         Clothing
# 80            10081  2024-03-21         Clothing
# 86            10087  2024-03-27         Clothing
# 92            10093  2024-04-02         Clothing
# 98            10099  2024-04-08         Clothing
# 104           10105  2024-04-14         Clothing
# ...

# %%
clothing[clothing["Unit Price"] > 99.99]
# narxi 100 dan qimmat bo'lgan kiyimlar
# Out:
#      Transaction ID        Date Product Category  \
# 14            10015  2024-01-15         Clothing
# 26            10027  2024-01-27         Clothing
# 44            10045  2024-02-14         Clothing
# 50            10051  2024-02-20         Clothing
# 194           10195  2024-07-13         Clothing
#
#                         Product Name  Units Sold  Unit Price  Total Revenue  \
# 14            North Face Down Jacket           2      249.99         499.98
# 26           Adidas Ultraboost Shoes           2      179.99         359.98
# 44          Patagonia Better Sweater           2      139.99         279.98
# 50        Ray-Ban Aviator Sunglasses           3      154.99         464.97
# 194  Adidas Ultraboost Running Shoes           2      179.99         359.98
#
#     Region Payment Method
# 14    Asia     Debit Card
# 26    Asia     Debit Card
# 44    Asia     Debit Card
# 50    Asia     Debit Card
# 194   Asia     Debit Card

# %%
df["Unit Price"].mean()
# mahsulotlarni o'rtacha narxi
# Out:
# 236.3955833333333

# %%
eu = df[df["Region"] == "Europe"]
eu[eu["Units Sold"] > 1].min()
# yevropada 1 tadan ko'p sotilgan mahsulotlarni eng arzoni
# Out:
# Transaction ID                                 10008
# Date                                      2024-01-08
# Product Category                     Beauty Products
# Product Name        Anastasia Beverly Hills Brow Wiz
# Units Sold                                         2
# Unit Price                                     14.99
# Total Revenue                                  29.98
# Region                                        Europe
# Payment Method                                PayPal
# dtype: object

# %%
eu
# Out:
#      Transaction ID        Date Product Category  \
# 1             10002  2024-01-02  Home Appliances
# 4             10005  2024-01-05  Beauty Products
# 7             10008  2024-01-08  Home Appliances
# 10            10011  2024-01-11  Beauty Products
# 13            10014  2024-01-14  Home Appliances
# ..              ...         ...              ...
# 226           10227  2024-08-14  Beauty Products
# 229           10230  2024-08-17  Home Appliances
# 232           10233  2024-08-20  Beauty Products
# 235           10236  2024-08-23  Home Appliances
# 238           10239  2024-08-26  Beauty Products
#
#                                         Product Name  Units Sold  Unit Price  \
# 1                                   Dyson V11 Vacuum           1      499.99
# 4                            Neutrogena Skincare Set           1       89.99
# 7                               Blueair Classic 480i           2      599.99
# ...

# %%
eu["Total Revenue"].median()
# yevropadagi sotuvlarni medianasi
# Out:
# 115.0

# %%
eu["Product Category"].value_counts()
# Out:
# Product Category
# Home Appliances    40
# Beauty Products    40
# Name: count, dtype: int64

# %%
eu.groupby(by="Units Sold")[["Unit Price", "Total Revenue"]].mean()
# bittada bir nechta olingan mahsulot o'rtacha narxlari
# Out:
#             Unit Price  Total Revenue
# Units Sold
# 1           168.185965     168.185965
# 2           255.988571     511.977143
# 3           154.990000     464.970000

# %%
df.groupby(by=["Region"])[["Unit Price"]].max()
# har bir regionda sotilgan eng qimmat mahsulot narxlari
# Out:
#                Unit Price
# Region
# Asia              1895.00
# Europe            1299.99
# North America     3899.99

# %%
df.groupby(by=["Region"])[["Unit Price"]].mean()
# har bir regiondagi mahsulot uchun o'rtacha narx
# Out:
#                Unit Price
# Region
# Asia            164.41025
# Europe          190.90425
# North America   353.87225

# %%
df.groupby(by=["Product Category"])[["Unit Price"]].max()
# har bir categoriyadagi eng qimmat mahsulot
# Out:
#                   Unit Price
# Product Category
# Beauty Products       399.99
# Books                  35.99
# Clothing              249.99
# Electronics          3899.99
# Home Appliances      1299.99
# Sports               1895.00

# %%
df.groupby(by=["Product Category"])[["Unit Price"]].mean()
# categoriyadagi mahsulotlar o'rtacha narxlari
# Out:
#                   Unit Price
# Product Category
# Beauty Products      61.6230
# Books                16.1530
# Clothing             67.5365
# Electronics         691.5915
# Home Appliances     320.1855
# Sports              261.2840
